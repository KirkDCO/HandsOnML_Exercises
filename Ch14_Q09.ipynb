# %% [markdown]
# <a href="https://colab.research.google.com/github/KirkDCO/HandsOnML_Exercises/blob/main/CH14_Q09.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from sklearn.metrics import confusion_matrix
from sklearn.metrics import accuracy_score

import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# Model / data parameters
num_classes = 10
input_shape = (28, 28, 1)

# the data, split between train and test sets
(X_train, y_train), (X_test, y_test) = keras.datasets.mnist.load_data()

# Scale images to the [0, 1] range
X_train = X_train.astype("float32") / 255
X_test = X_test.astype("float32") / 255
# Make sure images have shape (28, 28, 1)
X_train = np.expand_dims(X_train, -1)
X_test = np.expand_dims(X_test, -1)
print("X_train shape:", X_train.shape)
print(X_train.shape[0], "train samples")
print(X_test.shape[0], "test samples")


# convert class vectors to binary class matrices
y_train = keras.utils.to_categorical(y_train, num_classes)
y_test = keras.utils.to_categorical(y_test, num_classes)
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/mnist.npz
# 11493376/11490434 [==============================] - 0s 0us/step
# 11501568/11490434 [==============================] - 0s 0us/step
# X_train shape: (60000, 28, 28, 1)
# 60000 train samples
# 10000 test samples

# %%
# model similar to VGG16

# model = keras.models.Sequential([
#     keras.layers.Conv2D(64, 7, activation = 'relu', padding = 'same',
#                         input_shape = [28, 28, 1]),
#     keras.layers.MaxPooling2D(2),
#     keras.layers.Conv2D(128, 3, activation = 'relu', padding = 'same'),
#     keras.layers.Conv2D(128, 3, activation = 'relu', padding = 'same'),
#     keras.layers.MaxPooling2D(2),
#     keras.layers.Conv2D(256, 3, activation = 'relu', padding = 'same'),
#     keras.layers.Conv2D(256, 3, activation = 'relu', padding = 'same'),
#     keras.layers.MaxPooling2D(2),
#     keras.layers.Flatten(),
#     keras.layers.Dense(128, activation = 'relu'),
#     keras.layers.Dropout(0.5),
#     keras.layers.Dense(64),
#     keras.layers.Dropout(0.5),
#     keras.layers.Dense(10, activation = 'softmax')
# ])

# model similar to the one in the book 

model = keras.models.Sequential([
    keras.layers.Conv2D(32, kernel_size=3, padding="same", activation="relu"),
    keras.layers.Conv2D(64, kernel_size=3, padding="same", activation="relu"),
    keras.layers.MaxPool2D(),
    keras.layers.Flatten(),
    keras.layers.Dropout(0.25),
    keras.layers.Dense(128, activation="relu"),
    keras.layers.Dropout(0.5),
    keras.layers.Dense(10, activation="softmax")
])

# %%
# set up for a clean run
keras.backend.clear_session()
tf.random.set_seed(42)
np.random.seed(42)

# fit the model with callback option to test learning rate
model.compile(loss = 'categorical_crossentropy',
              optimizer = keras.optimizers.Nadam(),
              metrics = ['accuracy'])

history = model.fit(X_train, y_train, epochs =8,
                    validation_split = 0.15)

pd.DataFrame(history.history).plot(figsize = (8, 10))
plt.grid(True)
plt.gca().set_ylim(0, 1)
plt.show()

print(model.evaluate(X_train, y_train))
print(model.evaluate(X_test, y_test))
# Out:
# Epoch 1/25
# 1594/1594 [==============================] - 32s 13ms/step - loss: 0.1999 - accuracy: 0.9397 - val_loss: 0.0522 - val_accuracy: 0.9849
# Epoch 2/25
# 1594/1594 [==============================] - 20s 12ms/step - loss: 0.0831 - accuracy: 0.9750 - val_loss: 0.0403 - val_accuracy: 0.9886
# Epoch 3/25
# 1594/1594 [==============================] - 22s 14ms/step - loss: 0.0626 - accuracy: 0.9810 - val_loss: 0.0384 - val_accuracy: 0.9892
# Epoch 4/25
# 1594/1594 [==============================] - 20s 12ms/step - loss: 0.0482 - accuracy: 0.9849 - val_loss: 0.0456 - val_accuracy: 0.9868
# Epoch 5/25
# 1594/1594 [==============================] - 20s 12ms/step - loss: 0.0437 - accuracy: 0.9858 - val_loss: 0.0346 - val_accuracy: 0.9912
# Epoch 6/25
# 1594/1594 [==============================] - 19s 12ms/step - loss: 0.0356 - accuracy: 0.9892 - val_loss: 0.0344 - val_accuracy: 0.9913
# Epoch 7/25
# 1594/1594 [==============================] - 19s 12ms/step - loss: 0.0330 - accuracy: 0.9896 - val_loss: 0.0394 - val_accuracy: 0.9909
# Epoch 8/25
# 1594/1594 [==============================] - 19s 12ms/step - loss: 0.0293 - accuracy: 0.9907 - val_loss: 0.0336 - val_accuracy: 0.9917
# Epoch 9/25
# 1594/1594 [==============================] - 20s 13ms/step - loss: 0.0244 - accuracy: 0.9922 - val_loss: 0.0376 - val_accuracy: 0.9908
# Epoch 10/25
# 1594/1594 [==============================] - 20s 12ms/step - loss: 0.0260 - accuracy: 0.9920 - val_loss: 0.0428 - val_accuracy: 0.9913
# Epoch 11/25
# 1594/1594 [==============================] - 20s 12ms/step - loss: 0.0213 - accuracy: 0.9937 - val_loss: 0.0387 - val_accuracy: 0.9919
# Epoch 12/25
# 1594/1594 [==============================] - 19s 12ms/step - loss: 0.0210 - accuracy: 0.9932 - val_loss: 0.0524 - val_accuracy: 0.9894
# Epoch 13/25
# 1594/1594 [==============================] - 19s 12ms/step - loss: 0.0187 - accuracy: 0.9941 - val_loss: 0.0429 - val_accuracy: 0.9921
# Epoch 14/25
# 1594/1594 [==============================] - 19s 12ms/step - loss: 0.0181 - accuracy: 0.9941 - val_loss: 0.0423 - val_accuracy: 0.9914
# Epoch 15/25
# 1594/1594 [==============================] - 19s 12ms/step - loss: 0.0186 - accuracy: 0.9938 - val_loss: 0.0448 - val_accuracy: 0.9914
# Epoch 16/25
# 1594/1594 [==============================] - 19s 12ms/step - loss: 0.0166 - accuracy: 0.9945 - val_loss: 0.0444 - val_accuracy: 0.9917
# Epoch 17/25
# 1594/1594 [==============================] - 19s 12ms/step - loss: 0.0144 - accuracy: 0.9951 - val_loss: 0.0440 - val_accuracy: 0.9917
# Epoch 18/25
# 1594/1594 [==============================] - 22s 14ms/step - loss: 0.0151 - accuracy: 0.9954 - val_loss: 0.0433 - val_accuracy: 0.9926
# Epoch 19/25
# 1594/1594 [==============================] - 19s 12ms/step - loss: 0.0135 - accuracy: 0.9953 - val_loss: 0.0463 - val_accuracy: 0.9921
# Epoch 20/25
# 1594/1594 [==============================] - 19s 12ms/step - loss: 0.0137 - accuracy: 0.9955 - val_loss: 0.0511 - val_accuracy: 0.9922
# Epoch 21/25
# 1594/1594 [==============================] - 19s 12ms/step - loss: 0.0144 - accuracy: 0.9954 - val_loss: 0.0554 - val_accuracy: 0.9924
# Epoch 22/25
# 1594/1594 [==============================] - 19s 12ms/step - loss: 0.0132 - accuracy: 0.9958 - val_loss: 0.0469 - val_accuracy: 0.9924
# Epoch 23/25
# 1594/1594 [==============================] - 19s 12ms/step - loss: 0.0134 - accuracy: 0.9956 - val_loss: 0.0492 - val_accuracy: 0.9923
# Epoch 24/25
# 1594/1594 [==============================] - 21s 13ms/step - loss: 0.0122 - accuracy: 0.9960 - val_loss: 0.0508 - val_accuracy: 0.9920
# Epoch 25/25
# 1594/1594 [==============================] - 20s 13ms/step - loss: 0.0128 - accuracy: 0.9960 - val_loss: 0.0474 - val_accuracy: 0.9936
# 1875/1875 [==============================] - 9s 5ms/step - loss: 0.0076 - accuracy: 0.9989
# [0.007603634614497423, 0.9989333152770996]
# 313/313 [==============================] - 2s 5ms/step - loss: 0.0368 - accuracy: 0.9936
# [0.03682874143123627, 0.9936000108718872]

# %%
# add batchnorm
model = keras.models.Sequential([
    keras.layers.Conv2D(32, kernel_size=3, padding="same", activation="relu"),
    keras.layers.Conv2D(64, kernel_size=3, padding="same", activation="relu"),
    keras.layers.MaxPool2D(),
    keras.layers.BatchNormalization(),
    keras.layers.Flatten(),
    keras.layers.Dropout(0.25),
    keras.layers.Dense(128, activation='relu'),
    keras.layers.Dropout(0.5),
    keras.layers.Dense(10, activation="softmax")
])

# %%
keras.backend.clear_session()
tf.random.set_seed(42)
np.random.seed(42)

# fit the model with callback option to test learning rate
model.compile(loss = 'categorical_crossentropy',
              optimizer = keras.optimizers.Nadam(),
              metrics = ['accuracy'])

history = model.fit(X_train, y_train, epochs = 25,
                    validation_split = 0.15)

pd.DataFrame(history.history).plot(figsize = (8, 10))
plt.grid(True)
plt.gca().set_ylim(0, 1)
plt.show()

print(model.evaluate(X_train, y_train))
print(model.evaluate(X_test, y_test))
# Out:
# Epoch 1/25
# 1594/1594 [==============================] - 21s 12ms/step - loss: 0.2024 - accuracy: 0.9386 - val_loss: 0.0588 - val_accuracy: 0.9853
# Epoch 2/25
# 1594/1594 [==============================] - 19s 12ms/step - loss: 0.0933 - accuracy: 0.9730 - val_loss: 0.0596 - val_accuracy: 0.9823
# Epoch 3/25
# 1594/1594 [==============================] - 19s 12ms/step - loss: 0.0763 - accuracy: 0.9768 - val_loss: 0.0454 - val_accuracy: 0.9877
# Epoch 4/25
# 1594/1594 [==============================] - 20s 12ms/step - loss: 0.0650 - accuracy: 0.9815 - val_loss: 0.0612 - val_accuracy: 0.9849
# Epoch 5/25
# 1594/1594 [==============================] - 20s 13ms/step - loss: 0.0575 - accuracy: 0.9825 - val_loss: 0.0519 - val_accuracy: 0.9896
# Epoch 6/25
# 1594/1594 [==============================] - 20s 13ms/step - loss: 0.0507 - accuracy: 0.9853 - val_loss: 0.0601 - val_accuracy: 0.9887
# Epoch 7/25
# 1594/1594 [==============================] - 21s 13ms/step - loss: 0.0494 - accuracy: 0.9854 - val_loss: 0.0552 - val_accuracy: 0.9899
# Epoch 8/25
# 1594/1594 [==============================] - 20s 13ms/step - loss: 0.0459 - accuracy: 0.9873 - val_loss: 0.0517 - val_accuracy: 0.9909
# Epoch 9/25
# 1594/1594 [==============================] - 20s 12ms/step - loss: 0.0407 - accuracy: 0.9883 - val_loss: 0.0507 - val_accuracy: 0.9906
# Epoch 10/25
# 1594/1594 [==============================] - 20s 12ms/step - loss: 0.0397 - accuracy: 0.9889 - val_loss: 0.0563 - val_accuracy: 0.9896
# Epoch 11/25
# 1594/1594 [==============================] - 20s 12ms/step - loss: 0.0427 - accuracy: 0.9881 - val_loss: 0.0610 - val_accuracy: 0.9890
# Epoch 12/25
# 1594/1594 [==============================] - 20s 12ms/step - loss: 0.0376 - accuracy: 0.9894 - val_loss: 0.0564 - val_accuracy: 0.9892
# Epoch 13/25
# 1594/1594 [==============================] - 20s 12ms/step - loss: 0.0347 - accuracy: 0.9901 - val_loss: 0.0566 - val_accuracy: 0.9914
# Epoch 14/25
# 1594/1594 [==============================] - 20s 12ms/step - loss: 0.0326 - accuracy: 0.9908 - val_loss: 0.0710 - val_accuracy: 0.9909
# Epoch 15/25
# 1594/1594 [==============================] - 20s 12ms/step - loss: 0.0321 - accuracy: 0.9909 - val_loss: 0.0590 - val_accuracy: 0.9908
# Epoch 16/25
# 1594/1594 [==============================] - 20s 13ms/step - loss: 0.0320 - accuracy: 0.9907 - val_loss: 0.0682 - val_accuracy: 0.9888
# Epoch 17/25
# 1594/1594 [==============================] - 20s 12ms/step - loss: 0.0291 - accuracy: 0.9914 - val_loss: 0.0541 - val_accuracy: 0.9908
# Epoch 18/25
# 1594/1594 [==============================] - 20s 12ms/step - loss: 0.0277 - accuracy: 0.9923 - val_loss: 0.0741 - val_accuracy: 0.9904
# Epoch 19/25
# 1594/1594 [==============================] - 19s 12ms/step - loss: 0.0306 - accuracy: 0.9913 - val_loss: 0.0658 - val_accuracy: 0.9878
# Epoch 20/25
# 1594/1594 [==============================] - 19s 12ms/step - loss: 0.0277 - accuracy: 0.9920 - val_loss: 0.0609 - val_accuracy: 0.9912
# Epoch 21/25
# 1594/1594 [==============================] - 19s 12ms/step - loss: 0.0276 - accuracy: 0.9918 - val_loss: 0.0537 - val_accuracy: 0.9902
# Epoch 22/25
# 1594/1594 [==============================] - 20s 12ms/step - loss: 0.0233 - accuracy: 0.9937 - val_loss: 0.0643 - val_accuracy: 0.9911
# Epoch 23/25
# 1594/1594 [==============================] - 20s 13ms/step - loss: 0.0253 - accuracy: 0.9930 - val_loss: 0.0704 - val_accuracy: 0.9919
# Epoch 24/25
# 1594/1594 [==============================] - 20s 12ms/step - loss: 0.0249 - accuracy: 0.9932 - val_loss: 0.0581 - val_accuracy: 0.9903
# Epoch 25/25
# 1594/1594 [==============================] - 20s 13ms/step - loss: 0.0250 - accuracy: 0.9930 - val_loss: 0.0706 - val_accuracy: 0.9896
# 1875/1875 [==============================] - 9s 5ms/step - loss: 0.0129 - accuracy: 0.9977
# [0.012881319038569927, 0.9976833462715149]
# 313/313 [==============================] - 2s 5ms/step - loss: 0.0547 - accuracy: 0.9908
# [0.05468146875500679, 0.9908000230789185]

# %%
keras.backend.clear_session()
tf.random.set_seed(42)
np.random.seed(42)

# fit the model with callback option to test learning rate
model.compile(loss = 'categorical_crossentropy',
              optimizer = keras.optimizers.Nadam(),
              metrics = ['accuracy'])

# create a generator for training and validation sets
X_valid_sub = X_train[:10000, ]
X_train_sub = X_train[10000:, ]

from keras.preprocessing.image import ImageDataGenerator

datagen = ImageDataGenerator(rotation_range = 15, 
                             width_shift_range = .15,
                             height_shift_range = .15, 
                             fill_mode = 'nearest')
it_train = datagen.flow(X_train_sub, y_train_sub, batch_size = 32)

# fits the model on batches with real-time data augmentation:
history = model.fit(it_train,
                    validation_data = (X_valid_sub, y_valid_sub),
                    use_multiprocessing = True,
                    steps_per_epoch = len(it_train),
                    epochs = 50)

pd.DataFrame(history.history).plot(figsize = (8, 10))
plt.grid(True)
plt.gca().set_ylim(0, 1)
plt.show()

print(model.evaluate(X_train, y_train))
print(model.evaluate(X_test, y_test))
# Out:
# Epoch 1/50
# 1563/1563 [==============================] - 37s 22ms/step - loss: 0.0936 - accuracy: 0.9737 - val_loss: 0.0596 - val_accuracy: 0.9863
# Epoch 2/50
# 1563/1563 [==============================] - 34s 22ms/step - loss: 0.0955 - accuracy: 0.9742 - val_loss: 0.0356 - val_accuracy: 0.9898
# Epoch 3/50
# 1563/1563 [==============================] - 34s 22ms/step - loss: 0.0922 - accuracy: 0.9736 - val_loss: 0.0431 - val_accuracy: 0.9888
# Epoch 4/50
# 1563/1563 [==============================] - 34s 22ms/step - loss: 0.0893 - accuracy: 0.9755 - val_loss: 0.0382 - val_accuracy: 0.9901
# Epoch 5/50
# 1563/1563 [==============================] - 34s 22ms/step - loss: 0.0959 - accuracy: 0.9734 - val_loss: 0.0348 - val_accuracy: 0.9909
# Epoch 6/50
# 1563/1563 [==============================] - 33s 21ms/step - loss: 0.0894 - accuracy: 0.9759 - val_loss: 0.0494 - val_accuracy: 0.9885
# Epoch 7/50
# 1563/1563 [==============================] - 33s 21ms/step - loss: 0.0876 - accuracy: 0.9757 - val_loss: 0.0426 - val_accuracy: 0.9900
# Epoch 8/50
# 1563/1563 [==============================] - 33s 21ms/step - loss: 0.0879 - accuracy: 0.9754 - val_loss: 0.0466 - val_accuracy: 0.9879
# Epoch 9/50
# 1563/1563 [==============================] - 33s 21ms/step - loss: 0.0867 - accuracy: 0.9761 - val_loss: 0.0440 - val_accuracy: 0.9891
# Epoch 10/50
# 1563/1563 [==============================] - 33s 21ms/step - loss: 0.0867 - accuracy: 0.9762 - val_loss: 0.0564 - val_accuracy: 0.9875
# Epoch 11/50
# 1563/1563 [==============================] - 33s 21ms/step - loss: 0.0865 - accuracy: 0.9768 - val_loss: 0.0350 - val_accuracy: 0.9901
# Epoch 12/50
# 1563/1563 [==============================] - 35s 23ms/step - loss: 0.0850 - accuracy: 0.9765 - val_loss: 0.0316 - val_accuracy: 0.9925
# Epoch 13/50
# 1563/1563 [==============================] - 36s 23ms/step - loss: 0.0820 - accuracy: 0.9770 - val_loss: 0.0336 - val_accuracy: 0.9911
# Epoch 14/50
# 1563/1563 [==============================] - 36s 23ms/step - loss: 0.0865 - accuracy: 0.9765 - val_loss: 0.0350 - val_accuracy: 0.9907
# Epoch 15/50
# 1563/1563 [==============================] - 35s 22ms/step - loss: 0.0839 - accuracy: 0.9769 - val_loss: 0.0405 - val_accuracy: 0.9908
# Epoch 16/50
# 1563/1563 [==============================] - 34s 22ms/step - loss: 0.0844 - accuracy: 0.9765 - val_loss: 0.0464 - val_accuracy: 0.9887
# Epoch 17/50
# 1563/1563 [==============================] - 34s 22ms/step - loss: 0.0805 - accuracy: 0.9777 - val_loss: 0.0335 - val_accuracy: 0.9912
# Epoch 18/50
# 1563/1563 [==============================] - 33s 21ms/step - loss: 0.0808 - accuracy: 0.9775 - val_loss: 0.0318 - val_accuracy: 0.9916
# Epoch 19/50
# 1563/1563 [==============================] - 34s 21ms/step - loss: 0.0843 - accuracy: 0.9764 - val_loss: 0.0346 - val_accuracy: 0.9913
# Epoch 20/50
# 1563/1563 [==============================] - 34s 21ms/step - loss: 0.0849 - accuracy: 0.9763 - val_loss: 0.0296 - val_accuracy: 0.9925
# Epoch 21/50
# 1563/1563 [==============================] - 34s 22ms/step - loss: 0.0811 - accuracy: 0.9774 - val_loss: 0.0294 - val_accuracy: 0.9928
# Epoch 22/50
# 1563/1563 [==============================] - 33s 21ms/step - loss: 0.0839 - accuracy: 0.9769 - val_loss: 0.0413 - val_accuracy: 0.9906
# Epoch 23/50
# 1563/1563 [==============================] - 35s 22ms/step - loss: 0.0837 - accuracy: 0.9773 - val_loss: 0.0375 - val_accuracy: 0.9916
# Epoch 24/50
# 1563/1563 [==============================] - 35s 22ms/step - loss: 0.0792 - accuracy: 0.9780 - val_loss: 0.0364 - val_accuracy: 0.9901
# Epoch 25/50
# 1563/1563 [==============================] - 33s 21ms/step - loss: 0.0795 - accuracy: 0.9782 - val_loss: 0.0332 - val_accuracy: 0.9923
# Epoch 26/50
# 1563/1563 [==============================] - 34s 22ms/step - loss: 0.0844 - accuracy: 0.9773 - val_loss: 0.0361 - val_accuracy: 0.9903
# Epoch 27/50
# 1563/1563 [==============================] - 33s 21ms/step - loss: 0.0796 - accuracy: 0.9782 - val_loss: 0.0344 - val_accuracy: 0.9916
# Epoch 28/50
# 1563/1563 [==============================] - 34s 21ms/step - loss: 0.0777 - accuracy: 0.9781 - val_loss: 0.0308 - val_accuracy: 0.9917
# Epoch 29/50
# 1563/1563 [==============================] - 35s 22ms/step - loss: 0.0774 - accuracy: 0.9789 - val_loss: 0.0364 - val_accuracy: 0.9903
# Epoch 30/50
# 1563/1563 [==============================] - 35s 22ms/step - loss: 0.0791 - accuracy: 0.9783 - val_loss: 0.0268 - val_accuracy: 0.9922
# Epoch 31/50
# 1563/1563 [==============================] - 34s 22ms/step - loss: 0.0797 - accuracy: 0.9797 - val_loss: 0.0361 - val_accuracy: 0.9917
# Epoch 32/50
# 1563/1563 [==============================] - 34s 22ms/step - loss: 0.0785 - accuracy: 0.9789 - val_loss: 0.0279 - val_accuracy: 0.9918
# Epoch 33/50
# 1563/1563 [==============================] - 33s 21ms/step - loss: 0.0811 - accuracy: 0.9775 - val_loss: 0.0323 - val_accuracy: 0.9921
# Epoch 34/50
# 1563/1563 [==============================] - 34s 21ms/step - loss: 0.0788 - accuracy: 0.9787 - val_loss: 0.0399 - val_accuracy: 0.9911
# Epoch 35/50
# 1563/1563 [==============================] - 33s 21ms/step - loss: 0.0771 - accuracy: 0.9791 - val_loss: 0.0382 - val_accuracy: 0.9901
# Epoch 36/50
# 1563/1563 [==============================] - 35s 22ms/step - loss: 0.0749 - accuracy: 0.9795 - val_loss: 0.0331 - val_accuracy: 0.9915
# Epoch 37/50
# 1563/1563 [==============================] - 35s 22ms/step - loss: 0.0791 - accuracy: 0.9782 - val_loss: 0.0423 - val_accuracy: 0.9907
# Epoch 38/50
# 1563/1563 [==============================] - 33s 21ms/step - loss: 0.0776 - accuracy: 0.9786 - val_loss: 0.0401 - val_accuracy: 0.9902
# Epoch 39/50
# 1563/1563 [==============================] - 33s 21ms/step - loss: 0.0801 - accuracy: 0.9787 - val_loss: 0.0345 - val_accuracy: 0.9921
# Epoch 40/50
# 1563/1563 [==============================] - 34s 22ms/step - loss: 0.0827 - accuracy: 0.9782 - val_loss: 0.0315 - val_accuracy: 0.9923
# Epoch 41/50
# 1563/1563 [==============================] - 33s 21ms/step - loss: 0.0766 - accuracy: 0.9790 - val_loss: 0.0375 - val_accuracy: 0.9927
# Epoch 42/50
# 1563/1563 [==============================] - 35s 22ms/step - loss: 0.0776 - accuracy: 0.9784 - val_loss: 0.0293 - val_accuracy: 0.9931
# Epoch 43/50
# 1563/1563 [==============================] - 35s 22ms/step - loss: 0.0786 - accuracy: 0.9790 - val_loss: 0.0321 - val_accuracy: 0.9931
# Epoch 44/50
# 1563/1563 [==============================] - 35s 22ms/step - loss: 0.0739 - accuracy: 0.9795 - val_loss: 0.0340 - val_accuracy: 0.9919
# Epoch 45/50
# 1563/1563 [==============================] - 35s 22ms/step - loss: 0.0766 - accuracy: 0.9789 - val_loss: 0.0299 - val_accuracy: 0.9928
# Epoch 46/50
# 1563/1563 [==============================] - 33s 21ms/step - loss: 0.0751 - accuracy: 0.9793 - val_loss: 0.0405 - val_accuracy: 0.9919
# Epoch 47/50
# 1563/1563 [==============================] - 34s 22ms/step - loss: 0.0765 - accuracy: 0.9787 - val_loss: 0.0368 - val_accuracy: 0.9931
# Epoch 48/50
# 1563/1563 [==============================] - 33s 21ms/step - loss: 0.0745 - accuracy: 0.9802 - val_loss: 0.0302 - val_accuracy: 0.9919
# Epoch 49/50
# 1563/1563 [==============================] - 35s 22ms/step - loss: 0.0758 - accuracy: 0.9792 - val_loss: 0.0358 - val_accuracy: 0.9918
# Epoch 50/50
# 1563/1563 [==============================] - 33s 21ms/step - loss: 0.0764 - accuracy: 0.9790 - val_loss: 0.0270 - val_accuracy: 0.9937
# 1875/1875 [==============================] - 10s 5ms/step - loss: 0.0182 - accuracy: 0.9952
# [0.018235769122838974, 0.9951666593551636]
# 313/313 [==============================] - 2s 5ms/step - loss: 0.0192 - accuracy: 0.9948
# [0.01915111020207405, 0.9947999715805054]

# %%
model = keras.models.Sequential([
    keras.layers.Conv2D(64, 7, activation = 'relu', padding = 'same',
                        input_shape = [28, 28, 1]),
    keras.layers.MaxPooling2D(2),
    keras.layers.BatchNormalization(),
    keras.layers.Conv2D(128, 3, activation = 'relu', padding = 'same'),
    keras.layers.Conv2D(128, 3, activation = 'relu', padding = 'same'),
    keras.layers.MaxPooling2D(2),
    keras.layers.BatchNormalization(),
    keras.layers.Conv2D(256, 3, activation = 'relu', padding = 'same'),
    keras.layers.Conv2D(256, 3, activation = 'relu', padding = 'same'),
    keras.layers.MaxPooling2D(2),
    keras.layers.BatchNormalization(),
    keras.layers.Flatten(),
    keras.layers.Dense(128, activation = 'relu'),
    keras.layers.Dropout(0.5),
    keras.layers.Dense(64),
    keras.layers.Dropout(0.5),
    keras.layers.Dense(10, activation = 'softmax')
])

keras.backend.clear_session()
tf.random.set_seed(42)
np.random.seed(42)

# fit the model with callback option to test learning rate
model.compile(loss = 'categorical_crossentropy',
              optimizer = keras.optimizers.Nadam(),
              metrics = ['accuracy'])

# create a generator for training and validation sets
X_train_sub = X_train[10000:, ]
y_train_sub = y_train[10000:, ]
X_valid_sub = X_train[:10000, ]
y_valid_sub = y_train[:10000, ]

from keras.preprocessing.image import ImageDataGenerator

datagen = ImageDataGenerator(rotation_range = 15, 
                             width_shift_range = .15,
                             height_shift_range = .15, 
                             fill_mode = 'nearest')
it_train = datagen.flow(X_train_sub, y_train_sub, batch_size = 32)

# add learning rate scheduling 
def exponential_decay_fn(epoch):
  return 0.001 * 0.1 ** (epoch / 10)

lr_scheduler = keras.callbacks.LearningRateScheduler(exponential_decay_fn)

# add early stopping
early_stopping_cb = keras.callbacks.EarlyStopping(patience = 10, restore_best_weights = True)

# fits the model on batches with real-time data augmentation:
history = model.fit(it_train,
                    validation_data = (X_valid_sub, y_valid_sub),
                    use_multiprocessing = True,
                    steps_per_epoch = len(it_train),
                    epochs = 50,
                    callbacks = [early_stopping_cb, lr_scheduler])

pd.DataFrame(history.history).plot(figsize = (8, 10))
plt.grid(True)
plt.gca().set_ylim(0, 1)
plt.show()

print(model.evaluate(X_train, y_train))
print(model.evaluate(X_test, y_test))
# Out:
# Epoch 1/50
# 1563/1563 [==============================] - 63s 31ms/step - loss: 0.6072 - accuracy: 0.8240 - val_loss: 0.1357 - val_accuracy: 0.9706 - lr: 0.0010
# Epoch 2/50
# 1563/1563 [==============================] - 46s 29ms/step - loss: 0.1881 - accuracy: 0.9570 - val_loss: 0.0921 - val_accuracy: 0.9793 - lr: 7.9433e-04
# Epoch 3/50
# 1563/1563 [==============================] - 47s 30ms/step - loss: 0.1213 - accuracy: 0.9714 - val_loss: 0.0742 - val_accuracy: 0.9843 - lr: 6.3096e-04
# Epoch 4/50
# 1563/1563 [==============================] - 53s 34ms/step - loss: 0.0932 - accuracy: 0.9791 - val_loss: 0.0684 - val_accuracy: 0.9842 - lr: 5.0119e-04
# Epoch 5/50
# 1563/1563 [==============================] - 51s 33ms/step - loss: 0.0762 - accuracy: 0.9827 - val_loss: 0.0391 - val_accuracy: 0.9904 - lr: 3.9811e-04
# Epoch 6/50
# 1563/1563 [==============================] - 50s 32ms/step - loss: 0.0642 - accuracy: 0.9857 - val_loss: 0.0363 - val_accuracy: 0.9924 - lr: 3.1623e-04
# Epoch 7/50
# 1563/1563 [==============================] - 52s 33ms/step - loss: 0.0563 - accuracy: 0.9877 - val_loss: 0.0317 - val_accuracy: 0.9929 - lr: 2.5119e-04
# Epoch 8/50
# 1563/1563 [==============================] - 50s 32ms/step - loss: 0.0464 - accuracy: 0.9899 - val_loss: 0.0342 - val_accuracy: 0.9935 - lr: 1.9953e-04
# Epoch 9/50
# 1563/1563 [==============================] - 49s 32ms/step - loss: 0.0436 - accuracy: 0.9906 - val_loss: 0.0250 - val_accuracy: 0.9944 - lr: 1.5849e-04
# Epoch 10/50
# 1563/1563 [==============================] - 53s 34ms/step - loss: 0.0356 - accuracy: 0.9920 - val_loss: 0.0281 - val_accuracy: 0.9939 - lr: 1.2589e-04
# Epoch 11/50
# 1563/1563 [==============================] - 54s 35ms/step - loss: 0.0302 - accuracy: 0.9929 - val_loss: 0.0247 - val_accuracy: 0.9948 - lr: 1.0000e-04
# Epoch 12/50
# 1563/1563 [==============================] - 51s 32ms/step - loss: 0.0282 - accuracy: 0.9935 - val_loss: 0.0213 - val_accuracy: 0.9957 - lr: 7.9433e-05
# Epoch 13/50
# 1563/1563 [==============================] - 51s 33ms/step - loss: 0.0270 - accuracy: 0.9939 - val_loss: 0.0222 - val_accuracy: 0.9961 - lr: 6.3096e-05
# Epoch 14/50
# 1563/1563 [==============================] - 53s 34ms/step - loss: 0.0228 - accuracy: 0.9947 - val_loss: 0.0264 - val_accuracy: 0.9947 - lr: 5.0119e-05
# Epoch 15/50
# 1563/1563 [==============================] - 65s 41ms/step - loss: 0.0237 - accuracy: 0.9946 - val_loss: 0.0207 - val_accuracy: 0.9959 - lr: 3.9811e-05
# Epoch 16/50
# 1563/1563 [==============================] - 57s 36ms/step - loss: 0.0211 - accuracy: 0.9950 - val_loss: 0.0223 - val_accuracy: 0.9957 - lr: 3.1623e-05
# Epoch 17/50
# 1563/1563 [==============================] - 51s 32ms/step - loss: 0.0233 - accuracy: 0.9946 - val_loss: 0.0231 - val_accuracy: 0.9955 - lr: 2.5119e-05
# Epoch 18/50
# 1563/1563 [==============================] - 56s 35ms/step - loss: 0.0198 - accuracy: 0.9957 - val_loss: 0.0233 - val_accuracy: 0.9954 - lr: 1.9953e-05
# Epoch 19/50
# 1563/1563 [==============================] - 54s 35ms/step - loss: 0.0203 - accuracy: 0.9954 - val_loss: 0.0228 - val_accuracy: 0.9955 - lr: 1.5849e-05
# Epoch 20/50
# 1563/1563 [==============================] - 57s 36ms/step - loss: 0.0182 - accuracy: 0.9955 - val_loss: 0.0222 - val_accuracy: 0.9956 - lr: 1.2589e-05
# Epoch 21/50
# 1563/1563 [==============================] - 52s 33ms/step - loss: 0.0187 - accuracy: 0.9955 - val_loss: 0.0228 - val_accuracy: 0.9956 - lr: 1.0000e-05
# Epoch 22/50
# 1563/1563 [==============================] - 49s 31ms/step - loss: 0.0187 - accuracy: 0.9956 - val_loss: 0.0231 - val_accuracy: 0.9958 - lr: 7.9433e-06
# Epoch 23/50
# 1563/1563 [==============================] - 49s 31ms/step - loss: 0.0177 - accuracy: 0.9957 - val_loss: 0.0232 - val_accuracy: 0.9958 - lr: 6.3096e-06
# Epoch 24/50
# 1563/1563 [==============================] - 49s 31ms/step - loss: 0.0185 - accuracy: 0.9957 - val_loss: 0.0231 - val_accuracy: 0.9955 - lr: 5.0119e-06
# Epoch 25/50
# 1563/1563 [==============================] - 53s 34ms/step - loss: 0.0173 - accuracy: 0.9957 - val_loss: 0.0232 - val_accuracy: 0.9955 - lr: 3.9811e-06
# 1875/1875 [==============================] - 17s 9ms/step - loss: 0.0103 - accuracy: 0.9976
# [0.010331553407013416, 0.9976000189781189]
# 313/313 [==============================] - 3s 9ms/step - loss: 0.0162 - accuracy: 0.9957
# [0.016238398849964142, 0.9957000017166138]

# %%
# Kaggle version
# Previous code was used locally for testing and learning
# This version used the Kaggle dataset and was used to 
# create a Kaggle submission - 99.6% accurate,
# ranked in top 7.5% at the time.
# From here on, code should be able to stnad alone.

import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers

import random
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# Model / data parameters
num_classes = 10
input_shape = (28, 28, 1)

# the data, split between train and test sets
train = pd.read_csv('drive/MyDrive/Colab Notebooks/HandsOnML/DigitRecog/train.csv')
y_train = train['label']
X_train = train.drop('label', axis=1)

X_test = pd.read_csv('drive/MyDrive/Colab Notebooks/HandsOnML/DigitRecog/test.csv')

# Scale images to the [0, 1] range
X_train = X_train.astype("float32") / 255
X_test = X_test.astype("float32") / 255

# Make sure images have shape (28, 28, 1)
X_train = np.array(X_train).reshape(42000, 28, 28, 1)
X_test = np.array(X_test).reshape(28000, 28, 28, 1)

print("X_train shape:", X_train.shape)
print(X_train.shape[0], "train samples")
print(X_test.shape[0], "test samples")

# convert class vectors to binary class matrices
y_train = keras.utils.to_categorical(y_train, num_classes)
# Out:
# X_train shape: (42000, 28, 28, 1)
# 42000 train samples
# 28000 test samples

# %%
model = keras.models.Sequential([
    keras.layers.Conv2D(64, 7, activation = 'relu', padding = 'same',
                        input_shape = [28, 28, 1]),
    keras.layers.BatchNormalization(),
    keras.layers.MaxPooling2D(2),
    keras.layers.Conv2D(128, 3, activation = 'relu', padding = 'same'),
    keras.layers.Conv2D(128, 3, activation = 'relu', padding = 'same'),
    keras.layers.BatchNormalization(),
    keras.layers.MaxPooling2D(2),
    keras.layers.Conv2D(256, 3, activation = 'relu', padding = 'same'),
    keras.layers.Conv2D(256, 3, activation = 'relu', padding = 'same'),
    keras.layers.BatchNormalization(),
    keras.layers.MaxPooling2D(2),
    keras.layers.Flatten(),
    keras.layers.Dense(128, activation = 'relu'),
    keras.layers.Dropout(0.5),
    keras.layers.Dense(64),
    keras.layers.Dropout(0.25),
    keras.layers.Dense(10, activation = 'softmax')
])

keras.backend.clear_session()
tf.random.set_seed(720)
np.random.seed(720)

# fit the model with callback option to test learning rate
model.compile(loss = 'categorical_crossentropy',
              optimizer = keras.optimizers.Nadam(),
              metrics = ['accuracy'])

# create a generator for training and validation sets
X_train_sub = X_train[7500:, ]
y_train_sub = y_train[7500:, ]
X_valid_sub = X_train[:7500, ]
y_valid_sub = y_train[:7500, ]

from keras.preprocessing.image import ImageDataGenerator

datagen = ImageDataGenerator(rotation_range = 15, 
                             width_shift_range = .15,
                             height_shift_range = .15, 
                             fill_mode = 'nearest')
it_train = datagen.flow(X_train_sub, y_train_sub, batch_size = 32)

# add learning rate scheduling 
def exponential_decay_fn(epoch):
  return 0.001 * 0.1 ** (epoch / 10)

lr_scheduler = keras.callbacks.LearningRateScheduler(exponential_decay_fn)

# add early stopping
early_stopping_cb = keras.callbacks.EarlyStopping(patience = 10, restore_best_weights = True)

# fits the model on batches with real-time data augmentation:
history = model.fit(it_train,
                    validation_data = (X_valid_sub, y_valid_sub),
                    use_multiprocessing = True,
                    steps_per_epoch = len(it_train),
                    epochs = 50,
                    callbacks = [early_stopping_cb, lr_scheduler])

pd.DataFrame(history.history).plot(figsize = (8, 10))
plt.grid(True)
plt.gca().set_ylim(0, 1)
plt.show()
# Out:
# Epoch 1/50
# 1079/1079 [==============================] - 28s 15ms/step - loss: 0.8044 - accuracy: 0.7523 - val_loss: 0.1173 - val_accuracy: 0.9699 - lr: 0.0010
# Epoch 2/50
# 1079/1079 [==============================] - 16s 15ms/step - loss: 0.2263 - accuracy: 0.9424 - val_loss: 0.1043 - val_accuracy: 0.9744 - lr: 7.9433e-04
# Epoch 3/50
# 1079/1079 [==============================] - 16s 15ms/step - loss: 0.1524 - accuracy: 0.9636 - val_loss: 0.0717 - val_accuracy: 0.9844 - lr: 6.3096e-04
# Epoch 4/50
# 1079/1079 [==============================] - 15s 14ms/step - loss: 0.1129 - accuracy: 0.9740 - val_loss: 0.0550 - val_accuracy: 0.9843 - lr: 5.0119e-04
# Epoch 5/50
# 1079/1079 [==============================] - 16s 15ms/step - loss: 0.0913 - accuracy: 0.9782 - val_loss: 0.0454 - val_accuracy: 0.9880 - lr: 3.9811e-04
# Epoch 6/50
# 1079/1079 [==============================] - 15s 14ms/step - loss: 0.0761 - accuracy: 0.9813 - val_loss: 0.0340 - val_accuracy: 0.9901 - lr: 3.1623e-04
# Epoch 7/50
# 1079/1079 [==============================] - 15s 14ms/step - loss: 0.0579 - accuracy: 0.9860 - val_loss: 0.0623 - val_accuracy: 0.9860 - lr: 2.5119e-04
# Epoch 8/50
# 1079/1079 [==============================] - 15s 14ms/step - loss: 0.0521 - accuracy: 0.9877 - val_loss: 0.0334 - val_accuracy: 0.9923 - lr: 1.9953e-04
# Epoch 9/50
# 1079/1079 [==============================] - 15s 14ms/step - loss: 0.0439 - accuracy: 0.9898 - val_loss: 0.0303 - val_accuracy: 0.9921 - lr: 1.5849e-04
# Epoch 10/50
# 1079/1079 [==============================] - 15s 14ms/step - loss: 0.0397 - accuracy: 0.9905 - val_loss: 0.0320 - val_accuracy: 0.9924 - lr: 1.2589e-04
# Epoch 11/50
# 1079/1079 [==============================] - 15s 14ms/step - loss: 0.0324 - accuracy: 0.9917 - val_loss: 0.0296 - val_accuracy: 0.9935 - lr: 1.0000e-04
# Epoch 12/50
# 1079/1079 [==============================] - 15s 14ms/step - loss: 0.0348 - accuracy: 0.9917 - val_loss: 0.0231 - val_accuracy: 0.9941 - lr: 7.9433e-05
# Epoch 13/50
# 1079/1079 [==============================] - 15s 14ms/step - loss: 0.0271 - accuracy: 0.9935 - val_loss: 0.0248 - val_accuracy: 0.9941 - lr: 6.3096e-05
# Epoch 14/50
# 1079/1079 [==============================] - 15s 14ms/step - loss: 0.0262 - accuracy: 0.9936 - val_loss: 0.0264 - val_accuracy: 0.9951 - lr: 5.0119e-05
# Epoch 15/50
# 1079/1079 [==============================] - 15s 14ms/step - loss: 0.0239 - accuracy: 0.9943 - val_loss: 0.0245 - val_accuracy: 0.9952 - lr: 3.9811e-05
# Epoch 16/50
# 1079/1079 [==============================] - 15s 14ms/step - loss: 0.0230 - accuracy: 0.9944 - val_loss: 0.0228 - val_accuracy: 0.9955 - lr: 3.1623e-05
# Epoch 17/50
# 1079/1079 [==============================] - 15s 14ms/step - loss: 0.0195 - accuracy: 0.9952 - val_loss: 0.0232 - val_accuracy: 0.9949 - lr: 2.5119e-05
# Epoch 18/50
# 1079/1079 [==============================] - 15s 14ms/step - loss: 0.0198 - accuracy: 0.9950 - val_loss: 0.0240 - val_accuracy: 0.9948 - lr: 1.9953e-05
# Epoch 19/50
# 1079/1079 [==============================] - 15s 14ms/step - loss: 0.0166 - accuracy: 0.9959 - val_loss: 0.0238 - val_accuracy: 0.9953 - lr: 1.5849e-05
# Epoch 20/50
# 1079/1079 [==============================] - 15s 13ms/step - loss: 0.0189 - accuracy: 0.9953 - val_loss: 0.0226 - val_accuracy: 0.9953 - lr: 1.2589e-05
# Epoch 21/50
# 1079/1079 [==============================] - 15s 14ms/step - loss: 0.0170 - accuracy: 0.9954 - val_loss: 0.0228 - val_accuracy: 0.9949 - lr: 1.0000e-05
# Epoch 22/50
# 1079/1079 [==============================] - 15s 14ms/step - loss: 0.0160 - accuracy: 0.9961 - val_loss: 0.0225 - val_accuracy: 0.9955 - lr: 7.9433e-06
# Epoch 23/50
# 1079/1079 [==============================] - 15s 14ms/step - loss: 0.0177 - accuracy: 0.9954 - val_loss: 0.0226 - val_accuracy: 0.9955 - lr: 6.3096e-06
# Epoch 24/50
# 1079/1079 [==============================] - 15s 14ms/step - loss: 0.0185 - accuracy: 0.9952 - val_loss: 0.0230 - val_accuracy: 0.9955 - lr: 5.0119e-06
# Epoch 25/50
# 1079/1079 [==============================] - 15s 14ms/step - loss: 0.0160 - accuracy: 0.9957 - val_loss: 0.0233 - val_accuracy: 0.9956 - lr: 3.9811e-06
# Epoch 26/50
# 1079/1079 [==============================] - 15s 14ms/step - loss: 0.0162 - accuracy: 0.9957 - val_loss: 0.0231 - val_accuracy: 0.9955 - lr: 3.1623e-06
# Epoch 27/50
# 1079/1079 [==============================] - 15s 14ms/step - loss: 0.0162 - accuracy: 0.9958 - val_loss: 0.0237 - val_accuracy: 0.9956 - lr: 2.5119e-06
# Epoch 28/50
# 1079/1079 [==============================] - 15s 14ms/step - loss: 0.0159 - accuracy: 0.9959 - val_loss: 0.0233 - val_accuracy: 0.9956 - lr: 1.9953e-06
# Epoch 29/50
# 1079/1079 [==============================] - 15s 14ms/step - loss: 0.0161 - accuracy: 0.9957 - val_loss: 0.0234 - val_accuracy: 0.9956 - lr: 1.5849e-06
# Epoch 30/50
# 1079/1079 [==============================] - 15s 14ms/step - loss: 0.0165 - accuracy: 0.9956 - val_loss: 0.0234 - val_accuracy: 0.9955 - lr: 1.2589e-06
# Epoch 31/50
# 1079/1079 [==============================] - 15s 14ms/step - loss: 0.0180 - accuracy: 0.9959 - val_loss: 0.0234 - val_accuracy: 0.9955 - lr: 1.0000e-06
# Epoch 32/50
# 1079/1079 [==============================] - 15s 14ms/step - loss: 0.0165 - accuracy: 0.9963 - val_loss: 0.0234 - val_accuracy: 0.9955 - lr: 7.9433e-07

# %%
test_result = model.predict(X_test)

test_result = np.array(pd.DataFrame(test_result).idxmax(axis=1))

fig, ax = plt.subplots(5, 5, figsize=(8, 8))
fig.suptitle('Digits images and labels', fontsize=16)
ax = ax.ravel()
for i in range(25):
    sample_n = random.randint(0, X_test.shape[0])
    ax[i].imshow(np.array(X_test[sample_n]).reshape(28, 28), cmap='inferno')
    ax[i].get_xaxis().set_visible(False)
    ax[i].get_yaxis().set_visible(False)
    ax[i].set_title(test_result[sample_n], fontsize = 12)

plt.subplots_adjust(hspace=0.3)
fig.show()

predicted_data = pd.DataFrame({
    'ImageId': range(1, X_test.shape[0] + 1),
    'Label': test_result
})

predicted_data.to_csv('drive/MyDrive/Colab Notebooks/HandsOnML/DigitRecog/pred.csv', index=False)
